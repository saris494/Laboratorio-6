# %%
import pandas as pd

# %%
df =pd.read_csv(r"Datos\bicicletas_compartidas_bogota")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df =pd.read.csv(r"Datos\bicicletas_compartidas_bogota")
#
# NameError: name 'pd' is not defined
